# %%
l = []
l
# Out:
# []

# %%
l.append(10)
l.append(20)
l.append(30)
l.append(40)
l.append(50)
l
# Out:
# [10, 20, 30, 40, 50]

# %%
l.append(10)
l
# Out:
# [10, 20, 30, 40, 50, 10]

# %%
len(l)
# Out:
# 6

# %%
l1 = [10, 2.3 ,1+2j , "nit",[1,2,3]]
l1
# Out:
# [10, 2.3, (1+2j), 'nit', [1, 2, 3]]

# %%
print(id(l))
print(id(l1))
# Out:
# 1981069650944
# 1981088532352

# %%
l2 = l.copy()
l2
# Out:
# [10, 20, 30, 40, 50, 10]

# %%
print(id(l2))
# Out:
# 1981088830656

# %%
l2.clear()
len(l2)
# Out:
# 0

# %%
del l2

# %%
l2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 l2
#
# NameError: name 'l2' is not defined

# %%
l.count(20)
l.count(10)
# Out:
# 2

# %%
a = [1,2,3]
b = [4,5,6]
a.extend(b)
a
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
l3 = []
l3
# Out:
# []

# %%
l3.extend(l)
l3
# Out:
# [10, 20, 30, 40, 50, 10]

# %%
l3.extend(l1)
l3
# Out:
# [10, 20, 30, 40, 50, 10, 10, 2.3, (1+2j), 'nit', [1, 2, 3]]

# %%
l[0]
# Out:
# 10

# %%
l[0] = 100
l
# Out:
# [100, 20, 30, 40, 50, 10]

# %%
l[4]=500
l
# Out:
# [100, 20, 30, 40, 500, 10]

# %%
l.index(100)
# Out:
# 0

# %%
l3
# Out:
# [10, 20, 30, 40, 50, 10, 10, 2.3, (1+2j), 'nit', [1, 2, 3]]

# %%
l3.index(10)
# Out:
# 0

# %%
l.insert(2,25)
l
# Out:
# [100, 20, 25, 30, 40, 500, 10]

# %%
l3.pop()
# Out:
# [1, 2, 3]

# %%
l3
# Out:
# [10, 20, 30, 40, 50, 10, 10, 2.3, (1+2j), 'nit']

# %%
l3.pop(2)
# Out:
# 30

# %%
l3.remove(40)

# %%
l3
# Out:
# [10, 20, 50, 10, 10, 2.3, (1+2j), 'nit']

# %%
l.reverse()
l
# Out:
# [10, 500, 40, 30, 25, 20, 100]

# %%
l.sort()
l
# Out:
# [10, 20, 25, 30, 40, 100, 500]

# %%
l.sort(reverse=True)
l
# Out:
# [500, 100, 40, 30, 25, 20, 10]

# %%
5000 in l
# Out:
# False

# %%
500 in l
# Out:
# True
