# %%
s7={1,2,3,4,5}
s8={4,5,6,7,8}
s9={8,9,10}

# %%
s7.intersection(s8)
# Out:
# {4, 5}

# %%
s7.intersection(s9)
# Out:
# set()

# %%
s8&s9
# Out:
# {8}

# %%
s7.difference(s8)
# Out:
# {1, 2, 3}

# %%
s9 - s8
# Out:
# {9, 10}

# %%
s7.symmetric_difference(s8) # it will not display the common elements of both sets
# Out:
# {1, 2, 3, 6, 7, 8}

# %%
s8 ^ s9
# Out:
# {4, 5, 6, 7, 9, 10}

# %%
s7.symmetric_difference_update(s8) # it will update the set s7 by removing the common elements and adding the unique elements of s8 to s7

# %%
s7
# Out:
# {1, 2, 3, 6, 7, 8}

# %%
a={1,2,3,4,5,6,7,8,9}
b ={3,4,5,6,7,8}
c ={10,20,30,40}

# %%
a.issuperset(b)
# Out:
# True

# %%
c.isdisjoint(a)
# Out:
# True

# %%
c.isdisjoint(b)
# Out:
# True

# %%
a={1,2,3,4,5,6,7,8,9}
b ={30,40,50,60,70,80}
c ={10,20,30,40}

# %%
a.issuperset(b) # it will check if a is a superset of b or not
# Out:
# False

# %%
a.isdisjoint(b) # it will return false because both sets have common elements
# Out:
# True
